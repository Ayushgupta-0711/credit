# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Credit_Data.csv')
df
# Out:
#       ID   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0      1   14.891   3606     283      2   34         11    Male      No
# 1      2  106.025   6645     483      3   82         15  Female     Yes
# 2      3  104.593   7075     514      4   71         11    Male      No
# 3      4  148.924   9504     681      3   36         11  Female      No
# 4      5   55.882   4897     357      2   68         16    Male      No
# ..   ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395  396   12.096   4100     307      3   32         13    Male      No
# 396  397   13.364   3838     296      5   65         17    Male      No
# 397  398   57.872   4171     321      5   67         12  Female      No
# 398  399   37.728   2525     192      1   44         13    Male      No
# 399  400   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity  Balance
# 0       Yes         Caucasian      333
# 1       Yes             Asian      903
# 2        No             Asian      580
# 3        No             Asian      964
# 4       Yes         Caucasian      331
# ..      ...               ...      ...
# 395     Yes         Caucasian      560
# 396      No  African American      480
# 397     Yes         Caucasian      138
# 398     Yes         Caucasian        0
# 399      No             Asian      966
#
# [400 rows x 12 columns]

# %%
df.describe()
# Out:
#                ID      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# max     98.000000   20.000000  1999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         400 non-null    int64
#  1   Income     400 non-null    float64
#  2   Limit      400 non-null    int64
#  3   Rating     400 non-null    int64
#  4   Cards      400 non-null    int64
#  5   Age        400 non-null    int64
#  6   Education  400 non-null    int64
#  7   Gender     400 non-null    object
#  8   Student    400 non-null    object
#  9   Married    400 non-null    object
#  10  Ethnicity  400 non-null    object
#  11  Balance    400 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
df.describe(include='O')
# Out:
#         Gender Student Married  Ethnicity
# count      400     400     400        400
# unique       2       2       2          3
# top     Female      No     Yes  Caucasian
# freq       207     360     245        199

# %%
df.describe(exclude='O')
# Out:
#                ID      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# max     98.000000   20.000000  1999.000000

# %%
df.shape
# Out:
# (400, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       ID   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0      1   14.891   3606     283      2   34         11    Male      No
# 1      2  106.025   6645     483      3   82         15  Female     Yes
# 2      3  104.593   7075     514      4   71         11    Male      No
# 3      4  148.924   9504     681      3   36         11  Female      No
# 4      5   55.882   4897     357      2   68         16    Male      No
# ..   ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395  396   12.096   4100     307      3   32         13    Male      No
# 396  397   13.364   3838     296      5   65         17    Male      No
# 397  398   57.872   4171     321      5   67         12  Female      No
# 398  399   37.728   2525     192      1   44         13    Male      No
# 399  400   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity  Balance
# 0       Yes         Caucasian      333
# 1       Yes             Asian      903
# 2        No             Asian      580
# 3        No             Asian      964
# 4       Yes         Caucasian      331
# ..      ...               ...      ...
# 395     Yes         Caucasian      560
# 396      No  African American      480
# 397     Yes         Caucasian      138
# 398     Yes         Caucasian        0
# 399      No             Asian      966
#
# [400 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# Income       0
# Limit        0
# Rating       0
# Cards        0
# Age          0
# Education    0
# Gender       0
# Student      0
# Married      0
# Ethnicity    0
# Balance      0
# dtype: int64

# %%
df.dropna()
# Out:
#       ID   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0      1   14.891   3606     283      2   34         11    Male      No
# 1      2  106.025   6645     483      3   82         15  Female     Yes
# 2      3  104.593   7075     514      4   71         11    Male      No
# 3      4  148.924   9504     681      3   36         11  Female      No
# 4      5   55.882   4897     357      2   68         16    Male      No
# ..   ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395  396   12.096   4100     307      3   32         13    Male      No
# 396  397   13.364   3838     296      5   65         17    Male      No
# 397  398   57.872   4171     321      5   67         12  Female      No
# 398  399   37.728   2525     192      1   44         13    Male      No
# 399  400   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity  Balance
# 0       Yes         Caucasian      333
# 1       Yes             Asian      903
# 2        No             Asian      580
# 3        No             Asian      964
# 4       Yes         Caucasian      331
# ..      ...               ...      ...
# 395     Yes         Caucasian      560
# 396      No  African American      480
# 397     Yes         Caucasian      138
# 398     Yes         Caucasian        0
# 399      No             Asian      966
#
# [400 rows x 12 columns]

# %%
df.value_counts('Ethnicity')
# Out:
# Ethnicity
# Caucasian           199
# Asian               102
# African American     99
# Name: count, dtype: int64

# %%
df.drop(columns=['ID','Rating'],inplace=True)

# %%
df
# Out:
#       Income  Limit  Cards  Age  Education  Gender Student Married  \
# 0     14.891   3606      2   34         11    Male      No     Yes
# 1    106.025   6645      3   82         15  Female     Yes     Yes
# 2    104.593   7075      4   71         11    Male      No      No
# 3    148.924   9504      3   36         11  Female      No      No
# 4     55.882   4897      2   68         16    Male      No     Yes
# ..       ...    ...    ...  ...        ...     ...     ...     ...
# 395   12.096   4100      3   32         13    Male      No     Yes
# 396   13.364   3838      5   65         17    Male      No      No
# 397   57.872   4171      5   67         12  Female      No     Yes
# 398   37.728   2525      1   44         13    Male      No     Yes
# 399   18.701   5524      5   64          7  Female      No      No
#
#             Ethnicity  Balance
# 0           Caucasian      333
# 1               Asian      903
# 2               Asian      580
# 3               Asian      964
# 4           Caucasian      331
# ..                ...      ...
# 395         Caucasian      560
# 396  African American      480
# 397         Caucasian      138
# 398         Caucasian        0
# 399             Asian      966
#
# [400 rows x 10 columns]

# %%
df.dtypes
# Out:
# Income       float64
# Limit          int64
# Cards          int64
# Age            int64
# Education      int64
# Gender        object
# Student       object
# Married       object
# Ethnicity     object
# Balance        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Income', 'Limit', 'Cards', 'Age', 'Education', 'Gender', 'Student',
#        'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['Gender'] = encoder.fit_transform(df['Gender'])  
df['Student'] = encoder.fit_transform(df['Student'])
df['Married'] = encoder.fit_transform(df['Married'])
df['Ethnicity'] = encoder.fit_transform(df['Ethnicity'])

# %%
df.dtypes
# Out:
# Income       float64
# Limit          int64
# Cards          int64
# Age            int64
# Education      int64
# Gender         int32
# Student        int32
# Married        int32
# Ethnicity      int32
# Balance        int64
# dtype: object

# %%
df
# Out:
#       Income  Limit  Cards  Age  Education  Gender  Student  Married  \
# 0     14.891   3606      2   34         11       1        0        1
# 1    106.025   6645      3   82         15       0        1        1
# 2    104.593   7075      4   71         11       1        0        0
# 3    148.924   9504      3   36         11       0        0        0
# 4     55.882   4897      2   68         16       1        0        1
# ..       ...    ...    ...  ...        ...     ...      ...      ...
# 395   12.096   4100      3   32         13       1        0        1
# 396   13.364   3838      5   65         17       1        0        0
# 397   57.872   4171      5   67         12       0        0        1
# 398   37.728   2525      1   44         13       1        0        1
# 399   18.701   5524      5   64          7       0        0        0
#
#      Ethnicity  Balance
# 0            2      333
# 1            1      903
# 2            1      580
# 3            1      964
# 4            2      331
# ..         ...      ...
# 395          2      560
# 396          0      480
# 397          2      138
# 398          2        0
# 399          1      966
#
# [400 rows x 10 columns]

# %%
x = df.drop(['Balance'], axis=1)
y = df['Balance']

# %%
x.head()
# Out:
#     Income  Limit  Cards  Age  Education  Gender  Student  Married  Ethnicity
# 0   14.891   3606      2   34         11       1        0        1          2
# 1  106.025   6645      3   82         15       0        1        1          1
# 2  104.593   7075      4   71         11       1        0        0          1
# 3  148.924   9504      3   36         11       0        0        0          1
# 4   55.882   4897      2   68         16       1        0        1          2

# %%
y.head()
# Out:
# 0    333
# 1    903
# 2    580
# 3    964
# 4    331
# Name: Balance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       Income  Limit  Cards  Age  Education  Gender  Student  Married  \
# 3    148.924   9504      3   36         11       0        0        0
# 18    49.570   6384      1   28          9       0        0        1
# 202   21.038   1448      2   58         13       0        0        1
# 250   10.363   2430      2   47         18       0        0        1
# 274   30.550   5869      5   81          9       0        0        0
# ..       ...    ...    ...  ...        ...     ...      ...      ...
# 71    58.781   7402      2   81         12       0        0        1
# 106   16.819   1337      2   74         15       1        0        1
# 270   15.866   3085      1   39         13       1        0        0
# 348   13.433   1134      3   70         14       1        0        1
# 102   68.713   7582      2   56         16       1        1        0
#
#      Ethnicity
# 3            1
# 18           1
# 202          2
# 250          1
# 274          0
# ..         ...
# 71           1
# 106          1
# 270          2
# 348          2
# 102          2
#
# [320 rows x 9 columns]

# %%
y_train
# Out:
# 3       964
# 18      891
# 202       0
# 250       0
# 274     967
#        ...
# 71     1103
# 106       0
# 270     136
# 348       0
# 102    1587
# Name: Balance, Length: 320, dtype: int64

# %%
x_test
# Out:
#       Income  Limit  Cards  Age  Education  Gender  Student  Married  \
# 209  151.947   9156      2   91         11       0        0        1
# 280   53.401   5319      3   35         12       0        0        0
# 33    31.367   1829      4   30         10       1        0        1
# 210   24.543   3206      2   62         12       0        0        1
# 93    16.479   5435      2   26         16       1        0        0
# ..       ...    ...    ...  ...        ...     ...      ...      ...
# 246   19.588   3211      4   59         14       0        0        0
# 227   66.989   5614      3   47         14       0        0        1
# 369   71.682   8028      3   57         16       1        0        1
# 176   24.050   2607      4   32         18       1        0        1
# 289   10.852   3907      2   30          9       1        0        0
#
#      Ethnicity
# 209          0
# 280          0
# 33           2
# 210          2
# 93           0
# ..         ...
# 246          1
# 227          2
# 369          2
# 176          2
# 289          2
#
# [80 rows x 9 columns]

# %%
y_test
# Out:
# 209     732
# 280     541
# 33        0
# 210      95
# 93      937
#        ...
# 246     199
# 227     482
# 369    1208
# 176       0
# 289     485
# Name: Balance, Length: 80, dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
dtr.score(x_test,y_test)
# Out:
# 0.8448516845452083

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_train,y_train)
# Out:
# 0.991369195538684

# %%
rfr.score(x_test,y_test)
# Out:
# 0.9276953595290315

# %%
import joblib,pickle

# %%
joblib.dump(rfr,'randomforestregressor.lb')
# Out:
# ['randomforestregressor.lb']
